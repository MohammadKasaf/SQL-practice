# %% [markdown]
# SELECT Questions

# %%
# %sql
CREATE DATABASE IF NOT EXISTS select_practice;
use select_practice;

CREATE TABLE employees(
    employee_id INT,
    employee_name STRING,
    department_id INT,
    salary INT,
    joining_date DATE,
    city STRING
);

INSERT INTO employees VALUES
(101,'Ali',1,55000,'2022-01-15','Delhi'),
(102,'Sara',2,45000,'2021-03-20','Noida'),
(103,'Ahmed',1,65000,'2020-08-10','Gurgaon'),
(104,'Zoya',3,70000,'2023-02-18','Delhi'),
(105,'Usman',2,48000,'2022-09-01','Noida'),
(106,'Areeba',1,80000,'2019-12-12','Gurgaon'),
(107,'Aqsha',3,72000,'2021-05-25','Delhi'),
(108,'Rahul',4,50000,'2020-11-30','Mumbai'),
(109,'Priya',4,52000,'2022-06-15','Pune'),
(110,'John',1,90000,'2018-04-05','Bangalore');

# %%
# %sql
SELECT * FROM employees;

SELECT employee_name FROM employees;

SELECT salary FROM employees;

SELECT city FROM employees;

SELECT employee_name,salary FROM employees;

SELECT DISTINCT(city) FROM employees;

SELECT DISTINCT(department_id) FROM employees;

SELECT salary AS employee_salary FROM employees;

SELECT employee_name,salary,salary+5000 AS bonus_salary FROM employees;
